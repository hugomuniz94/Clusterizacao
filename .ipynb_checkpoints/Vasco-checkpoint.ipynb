# %%
import pandas as pd
import json
from pandas.io.json import json_normalize
import os
import win32com.client as win32

# %%
df_json = pd.read_json("C:/Users/Pichau/Downloads/vasco.json")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-fc330afa811c> in <module>
# ----> 1 df_json = pd.read_json("C:/Users/Pichau/Downloads/vasco.json")
#
# ~\anaconda3\envs\predict_future_sales\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     197                 else:
#     198                     kwargs[new_arg_name] = new_arg_value
# --> 199             return func(*args, **kwargs)
#     200
#     201         return cast(F, wrapper)
#
# ~\anaconda3\envs\predict_future_sales\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# ...

# %% [markdown]
# ### Importando arquivo Marcos Dias x Planaltina

# %%
with open('C:/Users/Pichau/Downloads/Marcos Dias x Planaltina.json') as json_data:
    data = json.load(json_data)

# %%
print(data)
# Out:
# {'$id': '1', '$type': 'LongoMatch.Core.Store.Project, LongoMatch.Core', 'ID': '01503725-ba50-4020-a8e2-73b3de909927', 'Dashboard': {'$id': '2', '$type': 'LongoMatch.Core.Store.Templates.Dashboard, LongoMatch.Core', 'ID': '4bebf8ef-983d-4596-bf0c-0d0165f10030', 'Version': 1, 'List': [{'$id': '3', '$type': 'LongoMatch.Core.Store.AnalysisEventButton, LongoMatch.Core', 'ShowSubcategories': True, 'TagsPerRow': 2, 'EventType': {'$id': '4', '$type': 'LongoMatch.Core.Store.AnalysisEventType, LongoMatch.Core', 'ID': 'a4a8525f-e808-4311-8b9c-67188907cb57', 'Tags': [], 'Name': '1', 'Color': '#550164FF', 'TagGoalPosition': False, 'TagFieldPosition': False, 'TagHalfFieldPosition': False, 'FieldPositionIsDistance': False, 'HalfFieldPositionIsDistance': False, 'SortMethod': 1}, 'Name': '1', 'BackgroundColor': '#550164FF', 'TagMode': 0, 'Start': 6000, 'Stop': 6000, 'Position': '360 20', 'Width': 150, 'Height': 60, 'TextColor': '#FAFAFFFF', 'HotKey': '-1 -1', 'BackgroundImage': None, 'ActionLinks': [
# ...

# %%
with open('C:/Users/Pichau/Downloads/Marcos Dias x Planaltina.json') as file:
    json.loads(file.read())
#data2 = json.load(json_file)

# %%
print(file)
# Out:
# <_io.TextIOWrapper name='C:/Users/Pichau/Downloads/Marcos Dias x Planaltina.json' mode='r' encoding='cp1252'>

# %% [markdown]
# ### Importando arquivo Tipologia

# %%
with open("C:/Users/Pichau/Downloads/Tipologia.json", encoding='utf-8-sig') as tipologia:
    data_tipo = json.load(tipologia)
#data2 = json.load(json_file)

# %%
data_tipo
# Out:
# {'$id': '1',
#  '$type': 'LongoMatch.Core.Store.Project, LongoMatch.Core',
#  'ID': '5d788a80-f19a-404d-82a7-a6ffec324c0b',
#  'Dashboard': {'$id': '2',
#   '$type': 'LongoMatch.Core.Store.Templates.Dashboard, LongoMatch.Core',
#   'ID': '3d8eff24-fd4e-4c4a-b793-653e9b464a27',
#   'Version': 1,
#   'List': [{'$id': '3',
#     '$type': 'LongoMatch.Core.Store.TagButton, LongoMatch.Core',
#     'Tag': {'$id': '4',
#      '$type': 'LongoMatch.Core.Store.Tag, LongoMatch.Core',
#      'Group': '1',
#      'Value': 'RECUPERACAO DE BOLA CAMPO DE DEFESA',
#      'HotKey': '-1 -1'},
#     'HotKey': '-1 -1',
#     'Name': 'RECUPERACAO DE BOLA CAMPO DE DEFESA',
#     'Position': '10 0',
#     'Width': 240,
#     'Height': 120,
#     'BackgroundColor': '#9EDFF1FF',
#     'TextColor': '#3B3B3CFF',
#     'BackgroundImage': None,
#     'ActionLinks': []},
#    {'$id': '5',
#     '$type': 'LongoMatch.Core.Store.TagButton, LongoMatch.Core',
#     'Tag': {'$id': '6',
# ...

# %%
df = pd.DataFrame(data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-039b238b38ef> in <module>
# ----> 1 df = pd.DataFrame(data)
#
# ~\anaconda3\envs\predict_future_sales\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     527
#     528         elif isinstance(data, dict):
# --> 529             mgr = init_dict(data, index, columns, dtype=dtype)
#     530         elif isinstance(data, ma.MaskedArray):
#     531             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\envs\predict_future_sales\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     285             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     286         ]
# --> 287     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     288
#     289
#
# ...

# %%
data.to_excel('Marcos_Dias_x_Planaltina.xlsx')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-51-5326285c33d7> in <module>
# ----> 1 data.to_excel('Marcos_Dias_x_Planaltina.xlsx')
#
# AttributeError: 'dict' object has no attribute 'to_excel'

# %%
data.keys()
# Out:
# dict_keys(['$id', '$type', 'ID', 'Dashboard', 'LocalTeamTemplate', 'VisitorTeamTemplate', 'EventTypes', 'Version', 'Timeline', 'Description', 'Periods', 'Timers', 'Playlists'])
